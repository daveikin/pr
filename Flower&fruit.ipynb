# %% [markdown]
# <a href="https://colab.research.google.com/github/daveikin/pr/blob/main/Flower%26fruit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 
# Import Packages
#
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import cv2
import random
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, Activation, Conv2D, MaxPooling2D, BatchNormalization

print('Packages imported.')
# Out:
# Packages imported.

# %%
#
# Read/Display images functions
#
convert = lambda category : int(category == 'flowers')

def read_images(path, use_convert):  
    X = []
    y = []
    for p in os.listdir(path):
        category = p.split(".")[0]
        if (use_convert):
            category = convert(category)
        img_array = cv2.imread(os.path.join(path, p), cv2.IMREAD_GRAYSCALE)
        new_img_array = cv2.resize(img_array, dsize=(80, 80))
        X.append(new_img_array)
        y.append(category)
    return (X, y)

def read_train_images(path):
    return read_images(path, True)

def read_test_images(path):
    return read_images(path, False)

def grid_display(list_of_images, list_of_titles=[], no_of_columns=2, figsize=(10,10)):
    fig = plt.figure(figsize=figsize)
    column = 0
    for i in range(len(list_of_images)):
        column += 1
        #  check for end of column and create a new figure
        if column == no_of_columns+1:
            fig = plt.figure(figsize=figsize)
            column = 1
        fig.add_subplot(1, no_of_columns, column)
        plt.imshow(list_of_images[i], cmap="gray")
        plt.axis('off')
        if len(list_of_titles) >= len(list_of_images):
            plt.title(list_of_titles[i])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
print('Reading train image files...')
main_dir = "/content/drive/My Drive/Rew"
train_dir = "Training"
path = os.path.join(main_dir,train_dir)
(X_train, y_train) = read_train_images(path)
print('Reading train image files done.')
# Out:
# Reading train image files...
# Reading train image files done.

# %%
# Show some sample images
#            
random_images = []
for i in range(5):
    r = random.randint(1,len(X_train)-1)    
    random_images.append(X_train[r])    
grid_display(random_images, [], 5, (25, 25))
#
# Show some sample images
#            
random_images = []
for i in range(5):
    r = random.randint(1,len(X_train)-1)    
    random_images.append(X_train[r])    
grid_display(random_images, [], 5, (25, 25))

# %%
#
# Make numpy arrays and normalize image data
#
X_train = np.array(X_train).reshape(-1, 80, 80, 1)
y_train = np.array(y_train)

X_train_normalized =  X_train / 255.0

print(f'X_train {X_train_normalized.shape}')
print(f'y_train {y_train.shape}')
# Out:
# X_train (701, 80, 80, 1)
# y_train (701,)

# %%
#
# Build Convolutional Neural Net 
#

model = Sequential()

input_shape = X_train_normalized.shape[1:]

# Adds a densely-connected layer with 64 units 
model.add(Conv2D(64,(3,3), activation = 'relu', input_shape = input_shape))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2,2)))

# Add another densely-connected convolution layer with 64 units 
model.add(Conv2D(64,(3,3), activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2,2)))

# Add another densely-connected convolution layer with 64 units 
model.add(Conv2D(64,(3,3), activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2,2)))

# Add flatten layer
model.add(Flatten())
model.add(Dense(64, activation='relu'))

# Add output neruon with sigmoid activation function
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer="adam",
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
#
# Train Network 
#
model.fit(X_train_normalized, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Train on 560 samples, validate on 141 samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 560/560 [==============================] - 4s 7ms/sample - loss: 0.0911 - acc: 0.9625 - val_loss: 0.0600 - val_acc: 1.0000
# Epoch 2/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 0.0134 - acc: 0.9929 - val_loss: 0.0072 - val_acc: 1.0000
# Epoch 3/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 0.0087 - acc: 0.9964 - val_loss: 0.0148 - val_acc: 1.0000
# Epoch 4/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 0.0018 - acc: 0.9982 - val_loss: 0.0135 - val_acc: 1.0000
# Epoch 5/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 1.8736e-04 - acc: 1.0000 - val_loss: 0.0051 - val_acc: 1.0000
# Epoch 6/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 1.0967e-04 - acc: 1.0000 - val_loss: 0.0063 - val_acc: 1.0000
# Epoch 7/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 4.0614e-05 - acc: 1.0000 - val_loss: 0.0112 - val_acc: 1.0000
# Epoch 8/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 6.9399e-05 - acc: 1.0000 - val_loss: 0.0177 - val_acc: 1.0000
# Epoch 9/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 1.2329e-05 - acc: 1.0000 - val_loss: 0.0254 - val_acc: 1.0000
# Epoch 10/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 5.1591e-05 - acc: 1.0000 - val_loss: 0.0411 - val_acc: 0.9929
# Epoch 11/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 9.4637e-06 - acc: 1.0000 - val_loss: 0.0552 - val_acc: 0.9929
# Epoch 12/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 3.0272e-05 - acc: 1.0000 - val_loss: 0.0706 - val_acc: 0.9929
# Epoch 13/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 3.7889e-06 - acc: 1.0000 - val_loss: 0.0767 - val_acc: 0.9858
# Epoch 14/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 1.8065e-05 - acc: 1.0000 - val_loss: 0.0756 - val_acc: 0.9858
# Epoch 15/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 5.3677e-06 - acc: 1.0000 - val_loss: 0.0636 - val_acc: 0.9858
# Epoch 16/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 4.6132e-06 - acc: 1.0000 - val_loss: 0.0493 - val_acc: 0.9858
# Epoch 17/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 3.9868e-06 - acc: 1.0000 - val_loss: 0.0362 - val_acc: 0.9858
# Epoch 18/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 2.6684e-06 - acc: 1.0000 - val_loss: 0.0258 - val_acc: 0.9929
# Epoch 19/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 5.5770e-06 - acc: 1.0000 - val_loss: 0.0183 - val_acc: 0.9929
# Epoch 20/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 3.3011e-06 - acc: 1.0000 - val_loss: 0.0125 - val_acc: 0.9929
# Epoch 21/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 4.4535e-06 - acc: 1.0000 - val_loss: 0.0081 - val_acc: 0.9929
# Epoch 22/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 1.0226e-05 - acc: 1.0000 - val_loss: 0.0055 - val_acc: 1.0000
# Epoch 23/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 9.2641e-06 - acc: 1.0000 - val_loss: 0.0033 - val_acc: 1.0000
# Epoch 24/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 5.2084e-06 - acc: 1.0000 - val_loss: 0.0017 - val_acc: 1.0000
# Epoch 25/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 1.4831e-05 - acc: 1.0000 - val_loss: 8.6065e-04 - val_acc: 1.0000
# Epoch 26/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 3.0420e-06 - acc: 1.0000 - val_loss: 3.9691e-04 - val_acc: 1.0000
# Epoch 27/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 4.1634e-06 - acc: 1.0000 - val_loss: 1.8848e-04 - val_acc: 1.0000
# Epoch 28/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 2.2941e-06 - acc: 1.0000 - val_loss: 9.2019e-05 - val_acc: 1.0000
# Epoch 29/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 1.0670e-05 - acc: 1.0000 - val_loss: 4.7223e-05 - val_acc: 1.0000
# Epoch 30/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 3.3727e-06 - acc: 1.0000 - val_loss: 2.6632e-05 - val_acc: 1.0000
# Epoch 31/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 6.0192e-06 - acc: 1.0000 - val_loss: 1.4849e-05 - val_acc: 1.0000
# Epoch 32/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 4.6744e-06 - acc: 1.0000 - val_loss: 9.5512e-06 - val_acc: 1.0000
# Epoch 33/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 3.2489e-06 - acc: 1.0000 - val_loss: 7.0518e-06 - val_acc: 1.0000
# Epoch 34/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 2.9700e-06 - acc: 1.0000 - val_loss: 6.0719e-06 - val_acc: 1.0000
# Epoch 35/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 5.1164e-05 - acc: 1.0000 - val_loss: 8.1563e-06 - val_acc: 1.0000
# Epoch 36/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 8.7967e-06 - acc: 1.0000 - val_loss: 1.4887e-05 - val_acc: 1.0000
# Epoch 37/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 5.1047e-06 - acc: 1.0000 - val_loss: 1.7922e-05 - val_acc: 1.0000
# Epoch 38/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 8.2505e-06 - acc: 1.0000 - val_loss: 1.9524e-05 - val_acc: 1.0000
# Epoch 39/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 2.1326e-06 - acc: 1.0000 - val_loss: 2.4537e-05 - val_acc: 1.0000
# Epoch 40/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 1.6297e-06 - acc: 1.0000 - val_loss: 3.5839e-05 - val_acc: 1.0000
# Epoch 41/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 2.6275e-06 - acc: 1.0000 - val_loss: 5.4682e-05 - val_acc: 1.0000
# Epoch 42/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 2.1442e-06 - acc: 1.0000 - val_loss: 9.9262e-05 - val_acc: 1.0000
# Epoch 43/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 1.7906e-06 - acc: 1.0000 - val_loss: 1.7097e-04 - val_acc: 1.0000
# Epoch 44/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 1.5539e-06 - acc: 1.0000 - val_loss: 2.5657e-04 - val_acc: 1.0000
# Epoch 45/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 3.2403e-06 - acc: 1.0000 - val_loss: 3.5010e-04 - val_acc: 1.0000
# Epoch 46/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 1.0780e-06 - acc: 1.0000 - val_loss: 4.3302e-04 - val_acc: 1.0000
# Epoch 47/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 1.6697e-06 - acc: 1.0000 - val_loss: 5.2045e-04 - val_acc: 1.0000
# Epoch 48/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 3.0362e-06 - acc: 1.0000 - val_loss: 6.1662e-04 - val_acc: 1.0000
# Epoch 49/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 1.7790e-06 - acc: 1.0000 - val_loss: 6.9305e-04 - val_acc: 1.0000
# Epoch 50/50
# 560/560 [==============================] - 1s 1ms/sample - loss: 3.0670e-06 - acc: 1.0000 - val_loss: 7.8180e-04 - val_acc: 1.0000

# %%
# 
# Predict
#
main_dir = "/content/drive/My Drive/Rew"
test_dir = "test"
test_path = os.path.join(main_dir,test_dir)
print('reading Test images...')
(X_test, y_test) = read_test_images(test_path)

X_test = np.array(X_test).reshape(-1, 80, 80, 1)
y_test = np.array(y_test)
X_test_normalized =  X_test / 255.0
print('Reading test images done')
# Out:
# reading Test images...
# Reading test images done

# %%
#
# Show some sample predictions
#
random_images = []
random_titles = []
for i in range(10):
    r = random.randint(1, len(X_test)-1)    
    random_images.append(X_test[r].reshape(80, 80))    
    pred =  model.predict(X_test_normalized[r].reshape(1, 80, 80, 1))
    if pred >= 0.5:        
        random_titles.append('Flowers')
    else:        
        random_titles.append('Fruit')
        
grid_display(random_images, random_titles, 5, (25, 25))

# %%
#
# Submission
#

predictions = model.predict(X_test_normalized)
predicted_val = [int(round(p[0])) for p in predictions]
submission_df = pd.DataFrame({'id':y_test, 'label':predicted_val})

# write data frame wot csv
submission_df.to_csv("/content/drive/My Drive/reww/submission.csv", index=False)

# %%
#
# Save and Load model
#
from keras.models import load_model

model_json = model.to_json()
with open("/content/drive/My Drive/reww/flowers_fruit_model.json", "w") as json_file:
    json_file.write(model_json)
    
# serialize weights to HDF5
model.save_weights("/content/drive/My Drive/reww/flowers_fruit_model.json.h5")

# %%
#
# Evaluate model with an image from internet
#
from tensorflow.keras.models import load_model, model_from_json
from tensorflow.keras.utils import CustomObjectScope
from tensorflow.keras.initializers import glorot_uniform

print(os.listdir("/content/drive/My Drive/reww/"))

with open('/content/drive/My Drive/reww/flowers_fruit_model.json', 'r') as f:
    loaded_model = model_from_json(f.read(), custom_objects={'GlorotUniform': glorot_uniform() })   
loaded_model.load_weights('/content/drive/My Drive/reww//flowers_fruit_model.json.h5')
    
print('model loaded')
loaded_model.compile(optimizer="adam",
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# ['flowers_fruit_model.json', 'flowers_fruit_model.json.h5']
# model loaded

# %%
import cv2
from PIL import Image
import requests
from io import BytesIO

#url='https://cdn.pixabay.com/photo/2017/03/21/14/24/cosmos-flower-2162284_960_720.jpg'
#url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQlDmuRJWhfSTQbSeo2duKNKycnbTNmYohhNfGZGqXt6kmYCRAL'
#url = 'https://images.ua.prom.st/210921679_w640_h640_cid2097451_pid62381801-fd5c566a.jpg'
#url='https://fermoved.ru/wp-content/uploads/2018/05/frukt-ovosh-ili-yagoda-600x450.jpg'
#url='http://ecology.md/pics/2014/08/yabloko.jpg'
#url='https://topflo.ru/pc/article_pic/p_statya_lilliya.jpg?1379762461'
url='http://filuz.ru/images/Fruits/IagodailiFrukt/%D0%90%D1%80%D0%B1%D1%83%D0%B7.jpg'
response = requests.get(url)
img = Image.open(BytesIO(response.content))

plt.imshow(img)
plt.title('Is this a Fruit or Flower?')
plt.show()


open_cv_image = np.array(img) 
open_cv_gray_image = cv2.cvtColor(open_cv_image, cv2.COLOR_BGR2GRAY)
open_cv_gray_image = cv2.resize(open_cv_gray_image, dsize=(80, 80)) 
open_cv_gray_image_scaled = open_cv_gray_image / 255.0


print (open_cv_gray_image_scaled.shape)
pred = loaded_model.predict(open_cv_gray_image_scaled.reshape(1, 80, 80, 1))[0][0]
if (pred > 0.5):
    print(f'Flofer {pred * 100}%')
else:
    print(f'Fruit {(1-pred)*100}%')
# Out:
# (80, 80)
# Fruit 95.37906721234322%
